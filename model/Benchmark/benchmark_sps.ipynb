# %% [markdown]
# # Benchmark Modell SPS

# %% [markdown]
# ## 1. Import Libraries und Daten

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#Import data
df = pd.read_csv("../../data/data_sps.txt", sep=" ")

# %% [markdown]
# ## 2. Filter Attributes
#
# Für das einfache Modell werden wir nur die Features nehmen, die auch stark mit der korngrösse Korrelieren. Dafür werden wir Rangkorrelation nach Spearman anwenden.

# %%
tmp = df.corr(method='spearman')['size_mm']
tmp = tmp[~tmp.index.isin(['size_mm'])]
tmp = tmp.abs().sort_values(ascending=False)
tmp.head(5)
# Out:
# centroid_frequency_S01     0.833981
# median_freq_S01            0.831667
# centroid_frequency2_M01    0.813797
# cv_S01                     0.812757
# median_freq_M01            0.796904
# Name: size_mm, dtype: float64

# %% [markdown]
# Die Attribute "centroid frequency" haben die stärkste Korrelation. Aus diesem Grund nehmen wir nur diese Attribute für den Benchmark.

# %%
filter_col = [col for col in df if col.startswith('centroid_frequency')]
filter_col.append("size_mm")
df = df[filter_col]

# %%
df.shape
# Out:
# (11254, 9)

# %% [markdown]
# Der neue Datensatz hat jetzt nur noch 9 Attribute (inklusiv die Zielvariable).

# %% [markdown]
# ## 3. Transformation

# %%
fig = plt.subplots(figsize=(15, 10))

for k in range(df.shape[1]):
    plt.subplot(3,3,k+1)
    sns.histplot(df.iloc[:, k])
    
plt.show()

# %% [markdown]
# Zurzeit haben wir überall eine bimodale und rechtsschiefe Verteilung der Daten.
# Um alle Systeme gleich zu behandeln, wennden wir auch eine Log-Transformaion der Zielvariable durchführen.

# %%
fig = plt.subplots(1, 2, figsize=(12, 3))
tmp = df['size_mm'].to_numpy()
plt.subplot(1,2,1)
p = sns.histplot(tmp)
p.set_title('Zielvariable ohne Transformation', loc='left')
plt.subplot(1,2,2)
p = sns.histplot(np.log(tmp))
p.set_title('Zielvariable mit Log-Transformation', loc='left')
sns.despine()
plt.show()

# %% [markdown]
# Der Plot zeigt, dass durch die empfohlene Transformation die Korngrösse normalverteilter gemacht wird. Durch die Transformation könnte durchaus eine Verbesserung des Modells erreicht werden.

# %% [markdown]
# ## 4. Benchmark Lineares Modell

# %%
df = df.sample(frac = 1).reset_index(drop = True)

# %%
X, y = df.drop(['size_mm'], axis=1), np.log(df['size_mm'])

# %%
model = LinearRegression()
model.fit(X,y)
cvs = cross_val_score(model, X, y, cv=5)
np.mean(cvs)
# Out:
# 0.7284785934826477

# %% [markdown]
# Mit 8 Attributen und logarithmieren der Zielvariable konnten wir einen R2 Score von ca. 70% erreichen. Dieser Wert wird allgemein bereits als gut angesehen. Dies nehmen wir als Benchmark für unsere MPA-Modelle.

# %% [markdown]
# #### 4.1 Residuenanalyse

# %%
y_pred = model.predict(X)
res = y_pred-y
np.mean(res)
# Out:
# 1.7609277580912604e-16

# %%
fig, ax = plt.subplots(1,3, figsize=(20, 5))

sns.residplot(x=y_pred,y=y,ax=ax[0])
ax[0].title.set_text("Residuen-Diagramm")

sns.histplot(res,kde=True,ax=ax[1])
ax[1].title.set_text("Histogramm der Residuen")

sm.qqplot(res, fit=True, line="45", ax=ax[2])
ax[2].title.set_text("Quantil-Quantil-Diagramm")
plt.show()

# %% [markdown]
# Interpretation:
# - die Residuen haben den Erwartungwert um 0 herum
# - eine Normalverteilung der Residuen ist ebenfalls vorhanden
# - ein systematischer Fehler erkennbar
