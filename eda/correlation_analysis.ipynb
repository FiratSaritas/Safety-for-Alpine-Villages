# %% [markdown]
# Correlated Features

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_table('./data/extract_mpa.txt', sep=' ')
corr = df.corr()

# %%
fig =plt.subplots(figsize=(20, 15))
p = sns.heatmap(corr, mask=corr < .9)
